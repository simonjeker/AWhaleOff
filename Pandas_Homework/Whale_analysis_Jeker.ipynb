# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

whales_df = Path('../Resources/whale_returns.csv')
whales_df = pd.read_csv(whales_df, index_col="Date", infer_datetime_format=True, parse_dates=True)
whales_df = whales_df.sort_index()
whales_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
#Cou nulls
whales_df.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
# Count mulls
whales_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Dropna function to drop nulls
whales_df.dropna(inplace=True)
whales_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %%
whales_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
algo_df = Path('../Resources/algo_returns.csv')
algo_df = pd.read_csv(algo_df, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_df = algo_df.sort_index()
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
#Identify nulls
algo_df.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %%
# Count mulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Dropna function to drop nulls
algo_df.dropna(inplace=True)
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %%
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
# Reading S&P 500 Closing Prices
sp500_df = Path('../Resources/sp500_history.csv')
sp500_df = pd.read_csv(sp500_df, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_df = sp500_df.sort_index()
sp500_df.head()
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
#Data type
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_df["Close"] = sp500_df["Close"].str.replace("$", "")
sp500_df["Close"]
# Out:
# Date
# 2012-10-01    1444.49
# 2012-10-02    1445.75
# 2012-10-03    1450.99
# 2012-10-04    1461.40
# 2012-10-05    1460.93
#                ...
# 2019-04-16    2907.06
# 2019-04-17    2900.45
# 2019-04-18    2905.03
# 2019-04-22    2907.97
# 2019-04-23    2933.68
# Name: Close, Length: 1649, dtype: object

# %%
#Data type
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Convert `order_total` from `object` to `float`
sp500_df["Close"] = sp500_df["Close"].str.replace('$', '')
sp500_df["Close"] = sp500_df["Close"].astype("float")
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %% [markdown]
# sp500_df.head()

# %%
sp500_df.head()
# Out:
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate the daily return using the 'shift()' function
daily_returns = sp500_df.pct_change()
daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
#Drop nulls
daily_returns.dropna(inplace=True)
daily_returns
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457
# ...              ...
# 2019-04-16  0.000509
# 2019-04-17 -0.002274
# 2019-04-18  0.001579
# 2019-04-22  0.001012
# 2019-04-23  0.008841
#
# [1648 rows x 1 columns]

# %%
daily_returns = daily_returns.rename(columns={
    "Close": "SP500"
})

daily_returns.head()
# Out:
#                SP500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Concatenate DataFrames by columns and perform an inner join
combined_returns = pd.concat([whales_df, algo_df, daily_returns], axis="columns", join="inner")
combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %%
combined_returns.plot(figsize=(20,10), title="Daily Returns")

# %%
cumulative_returns = (1 + combined_returns).cumprod()
cumulative_returns.plot(figsize=(20,10), title="Cumulative Returns")

# %%
 
#Algo 1 is the clear winner, followed by Berkshire Hathaway INC, the only whale fund beating the S&P500. all other funds were clearly underperformed the S&P500.
#Paulson & CO INC was the only fund continously underperformimg the SP500. #boo

# Box plot to visually show risk

combined_returns.plot.box(figsize=(20, 10), title="Portfolio Risk")

# %%
#Analysis:
#Tiger Global has the widest spread compared to others. While it's symmetric with a ~short IQR, it has some far spread outliers --Definitely riskier.
#Paulson&Co has the smallest spread, it's symmetrical as well, short IQR and short range of whiskers, too and no crazy outliers. Least risky.
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. 
# Which portfolios are riskier than the S&P 500?
combined_returns.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# SP500                          0.008554
# dtype: float64

# %%
#Riskiest portfolio
sp500_bar = combined_returns["SP500"].std()
combined_returns.std() > sp500_bar
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SP500                          False
# dtype: bool

# %%
#Anual std
combined_returns.std() * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# SP500                          0.135786
# dtype: float64

# %%
#Rolling 21 window
combined_returns.rolling(window=21).std().plot(figsize=(20, 10), title="21 Day Rolling Standard Deviation")

# %%
#Analysis: I'd say most funds' risk increases with the S&P500 with the exception of Tiger Global which has a few more dramatic spikes in volatility.

#Correlation

correlation = combined_returns.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699914
# PAULSON & CO.INC.                             0.699914            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561243            0.434479
# BERKSHIRE HATHAWAY INC                        0.754360            0.545623
# Algo 1                                        0.321211            0.268840
# Algo 2                                        0.826873            0.678152
# SP500                                         0.837864            0.669732
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561243
# PAULSON & CO.INC.                               0.434479
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424423
# Algo 1                                          0.164387
# ...

# %%
#Analysis of correlation table: (Not sure I understand it correctly) It seems that Algo 2 at .858... has a very strong correlation to the SP500,
# as well as Soros Fund at .837....

# Beta
covariance = combined_returns["Algo 1"].rolling(window=60).cov(combined_returns["SP500"])
variance = combined_returns["SP500"].rolling(21).var()
(covariance / variance).plot(figsize=(20, 10), title="Algo 1 Beta")

# %%
#Analysis of Algo 1 Beta: Not sure I'm reading it well, but I don't think it is.
#Expo Weighted Avrg. formula: df['XYZ'].ewm(span= halflife = x) add.std().plot(figsize X) and title
combined_returns.ewm(halflife=21).std().plot(figsize=(20, 10), title="EWA")

# %%
# Calculate annualized Sharpe Ratios
sharpe_ratios = (combined_returns.mean() * 252) / (combined_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP500                          0.648267
# dtype: float64

# %%
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %%
# Analysisusing sharpe ratio:Algo 1 is the clear winner compared to all others. Algo 2 has a higher risk level than the sp500 while Berkshire is about the same.

amzn_historical_csv = Path("../Resources/AMZN_Revised.csv")
amzn_historical = pd.read_csv(amzn_historical_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
amzn_historical = amzn_historical.sort_index()
amzn_historical.head()
# Out:
#                AMZN
# Date
# 2018-05-11  1602.91
# 2018-05-14  1601.54
# 2018-05-15  1576.12
# 2018-05-16  1587.28
# 2018-05-17  1581.76

# %%
nflx_historical_csv = Path("../Resources/NFLX_Revised.csv")
nflx_historical = pd.read_csv(nflx_historical_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
nflx_historical = nflx_historical.sort_index()
nflx_historical.head()
# Out:
#               NFLX
# Date
# 2018-05-11  326.46
# 2018-05-14  328.53
# 2018-05-15  326.13
# 2018-05-16  328.19
# 2018-05-17  325.22

# %%
nvda_historical_csv = Path("../Resources/NVDA_Revised.csv")
nvda_historical = pd.read_csv(nvda_historical_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
nvda_historical = nvda_historical.sort_index()
nvda_historical.head()
# Out:
#               NVDA
# Date
# 2018-05-11  254.53
# 2018-05-14  255.36
# 2018-05-15  245.56
# 2018-05-16  246.01
# 2018-05-17  247.71

# %%
tsla_historical_csv = Path("../Resources/TSLA-Revised.csv")
tsla_historical = pd.read_csv(tsla_historical_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
tsla_historical = tsla_historical.sort_index()
tsla_historical.head()
# Out:
#              TSLA
# Date
# 2018-05-11  60.21
# 2018-05-14  58.39
# 2018-05-15  56.84
# 2018-05-16  57.30
# 2018-05-17  56.91

# %%
stock_portfolio = pd.concat([amzn_historical, nvda_historical, nflx_historical, tsla_historical], axis="columns", join="inner")
stock_portfolio.head()
# Out:
#                AMZN    NVDA    NFLX   TSLA
# Date
# 2018-05-11  1602.91  254.53  326.46  60.21
# 2018-05-14  1601.54  255.36  328.53  58.39
# 2018-05-15  1576.12  245.56  326.13  56.84
# 2018-05-16  1587.28  246.01  328.19  57.30
# 2018-05-17  1581.76  247.71  325.22  56.91

# %%
daily_returns =stock_portfolio.pct_change()
daily_returns.head()
# Out:
#                 AMZN      NVDA      NFLX      TSLA
# Date
# 2018-05-11       NaN       NaN       NaN       NaN
# 2018-05-14 -0.000855  0.003261  0.006341 -0.030228
# 2018-05-15 -0.015872 -0.038377 -0.007305 -0.026546
# 2018-05-16  0.007081  0.001833  0.006316  0.008093
# 2018-05-17 -0.003478  0.006910 -0.009050 -0.006806

# %%
daily_returns = daily_returns.dropna()
daily_returns.head()
# Out:
#                 AMZN      NVDA      NFLX      TSLA
# Date
# 2018-05-14 -0.000855  0.003261  0.006341 -0.030228
# 2018-05-15 -0.015872 -0.038377 -0.007305 -0.026546
# 2018-05-16  0.007081  0.001833  0.006316  0.008093
# 2018-05-17 -0.003478  0.006910 -0.009050 -0.006806
# 2018-05-18 -0.004672 -0.007145 -0.003198  0.000000

# %%
weights = [1/4, 1/4, 1/4, 1/4]
portfolio_returns = daily_returns.dot(weights)
portfolio_returns.head()
# Out:
# Date
# 2018-05-14   -0.005370
# 2018-05-15   -0.022025
# 2018-05-16    0.005831
# 2018-05-17   -0.003106
# 2018-05-18   -0.003754
# dtype: float64

# %%
combined_returns["Simon Fund"] = portfolio_returns
combined_returns.tail()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
# 2019-04-23                   0.007167            0.003485
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
# 2019-04-23                     0.006472                0.013278  0.004969
#
#               Algo 2     SP500  Simon Fund
# Date
# 2019-04-16  0.002899  0.000509    0.021324
# 2019-04-17 -0.005228 -0.002274   -0.006186
# ...

# %%
combined_returns.std() * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# SP500                          0.135786
# Simon Fund                     0.356204
# dtype: float64

# %%
combined_returns.rolling(window=21).std().plot(figsize=(20, 10), title="21 Day Rolling Standard Deviation")

# %%
sharpe_ratios = (combined_returns.mean() * 252) / (combined_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP500                          0.648267
# Simon Fund                     0.267027
# dtype: float64

# %%
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")

# %%
df = combined_returns.corr()
df.style.background_gradient(cmap="copper")
# Out:
# <style  type="text/css" >
#     #T_b1e051bc_f6aa_11ea_89ae_f8ac6504062crow0_col0 {
#             background-color:  #ffc77f;
#             color:  #000000;
#         }    #T_b1e051bc_f6aa_11ea_89ae_f8ac6504062crow0_col1 {
#             background-color:  #b9754b;
#             color:  #000000;
#         }    #T_b1e051bc_f6aa_11ea_89ae_f8ac6504062crow0_col2 {
#             background-color:  #955f3c;
#             color:  #f1f1f1;
#         }    #T_b1e051bc_f6aa_11ea_89ae_f8ac6504062crow0_col3 {
#             background-color:  #ce8253;
#             color:  #000000;
#         }    #T_b1e051bc_f6aa_11ea_89ae_f8ac6504062crow0_col4 {
#             background-color:  #3b2518;
#             color:  #f1f1f1;
#         }    #T_b1e051bc_f6aa_11ea_89ae_f8ac6504062crow0_col5 {
#             background-color:  #ee9760;
#             color:  #000000;
#         }    #T_b1e051bc_f6aa_11ea_89ae_f8ac6504062crow0_col6 {
#             background-color:  #f59b63;
#             color:  #000000;
# ...

# %%
#Beta
covariance = combined_returns["Simon Fund"].rolling(window=60).cov(combined_returns["SP500"])
variance = combined_returns["SP500"].rolling(60).var()
(covariance / variance).plot(figsize=(20, 10), title="Simon Fund Beta")

# %%
#Analysis:
